# %%
# !pip install pandas fiona shapely pyproj rtree # à faire obligatoirement en premier pour utiliser rtree ou pygeos pour les jointures spatiales
# !pip install contextily
# !pip install geopandas
# !pip install topojson
# Out:
# Requirement already satisfied: pandas in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (1.4.4)
# Collecting fiona
#   Downloading Fiona-1.9.4.post1-cp39-cp39-macosx_10_15_x86_64.whl (18.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.6/18.6 MB 5.2 MB/s eta 0:00:0000:0100:01m
# Collecting shapely
#   Downloading shapely-2.0.1-cp39-cp39-macosx_10_9_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 4.6 MB/s eta 0:00:0000:0100:01
# Collecting pyproj
#   Downloading pyproj-3.6.0-cp39-cp39-macosx_10_9_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 5.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: rtree in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (0.9.7)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.22.4)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: click~=8.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona) (8.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona) (21.4.0)
# Requirement already satisfied: certifi in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona) (2023.5.7)
# Requirement already satisfied: six in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona) (1.16.0)
# Requirement already satisfied: importlib-metadata in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona) (4.11.3)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->fiona) (3.8.0)
# Installing collected packages: shapely, pyproj, cligj, click-plugins, fiona
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.4.post1 pyproj-3.6.0 shapely-2.0.1
# Collecting contextily
#   Downloading contextily-1.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: requests in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from contextily) (2.31.0)
# Collecting xyzservices
#   Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 402.9 kB/s eta 0:00:00a 0:00:01
# Collecting geopy
#   Downloading geopy-2.3.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 798.0 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from contextily) (1.3.2)
# Collecting rasterio
#   Downloading rasterio-1.3.8-cp39-cp39-macosx_10_15_x86_64.whl (22.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.9/22.9 MB 4.5 MB/s eta 0:00:0000:0100:01
# Collecting mercantile
#   Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from contextily) (9.2.0)
# Requirement already satisfied: matplotlib in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from contextily) (3.5.2)
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (1.22.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->contextily) (4.25.0)
# Requirement already satisfied: click>=3.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from mercantile->contextily) (8.0.4)
# Requirement already satisfied: certifi in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (2023.5.7)
# Requirement already satisfied: cligj>=0.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: attrs in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (21.4.0)
# Requirement already satisfied: setuptools in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from rasterio->contextily) (68.0.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting affine
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from requests->contextily) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from requests->contextily) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from requests->contextily) (2.0.4)
# Requirement already satisfied: six>=1.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Installing collected packages: xyzservices, snuggs, mercantile, geographiclib, affine, rasterio, geopy, contextily
# Successfully installed affine-2.4.0 contextily-1.3.0 geographiclib-2.0 geopy-2.3.0 mercantile-1.2.1 rasterio-1.3.8 snuggs-1.4.7 xyzservices-2023.7.0
# Collecting geopandas
#   Downloading geopandas-0.13.2-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.6 MB/s eta 0:00:00a 0:00:010m
# Requirement already satisfied: shapely>=1.7.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: fiona>=1.8.19 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: pandas>=1.1.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (1.4.4)
# Requirement already satisfied: packaging in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (21.3)
# Requirement already satisfied: pyproj>=3.0.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: click~=8.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: importlib-metadata in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (4.11.3)
# Requirement already satisfied: attrs>=19.2.0 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (21.4.0)
# Requirement already satisfied: certifi in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: six in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.18.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata->fiona>=1.8.19->geopandas) (3.8.0)
# Installing collected packages: geopandas
# Successfully installed geopandas-0.13.2
# Collecting topojson
#   Downloading topojson-1.5-py2.py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.4/82.4 kB 430.8 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: shapely in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from topojson) (2.0.1)
# Requirement already satisfied: numpy in /Users/augustincablant/opt/anaconda3/lib/python3.9/site-packages (from topojson) (1.22.4)
# Installing collected packages: topojson
# Successfully installed topojson-1.5

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as pl 

# bibliotèques utiles pour les données géospatiales
